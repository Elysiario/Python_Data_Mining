# %%
from selenium import webdriver
from time import sleep as sl
import pandas as pd
import pyautogui as py

df = pd.read_excel('melhores_acoes.xlsx')
display(df)
# df será a variável que terá nosso DataFrame
# Out:
#     SETOR  TIPO              SETOR.1  COTAÇÃO ATUAL  MINIMO  MAXIMO  \
# 0   ABCB4  Ação  Financeiro e Outros          18.14   13.85   21.24
# 1  ALUP11  Ação    Utilidade Pública          29.45   22.45   30.24
# 2   CMIG3  Ação    Utilidade Pública          17.97   14.32   20.37
# 3   CMIG4  Ação    Utilidade Pública          12.60    9.57   12.86
# 4   JBSS3  Ação  Consumo não Cíclico          17.75   15.28   30.19
# 5  SAPR11  Ação    Utilidade Pública          20.92   15.24   21.21
# 6   SAPR4  Ação    Utilidade Pública           4.23    3.11    4.25
# 7   SLCE3  Ação  Consumo não Cíclico          40.81   34.42   49.03
# 8   VALE3  Ação    Materiais Básicos          65.46   61.39   95.89
#
#    DIVIDEND YIELD  LIQUIDEZ DIÁRIA  P/VP  CAGR LUCRO  PATRIMÔNIO LÍQUIDO  \
# 0            8.64     1.850763e+07  0.78       12.65          5290796000
# 1            5.30     2.554884e+07  1.25       16.77          7183092000
# 2            6.29     6.404086e+06  1.74       32.15         22791065000
# 3            8.96     1.315602e+08  1.22       32.15         22791065000
# 4           11.27     2.267526e+08  0.88       75.38         44642552000
# 5            8.76     2.238613e+07  0.69       11.44          9106461000
# 6            8.83     9.979150e+06  0.70       11.44          9106461000
# 7            7.22     7.623027e+07  1.77       24.39          5218264000
# 8            8.70     2.032931e+09  1.57       36.13        189678000000
#
#       CAIXA     LUCRO
# 0   3559.27     80023
# 1   2313.71    189983
# 2   6613.08    409437
# 3   6613.08    409437
# 4  13333.51   1620125
# 5   1991.25    115154
# 6   1991.25    115154
# 7   1991.78    180583
# 8  58201.00  10170400

# %%
navegador = webdriver.Chrome()
navegador.get('https://www.google.com')
link = 'https://statusinvest.com.br/'
navegador.get(link)
print(link)
#as funcões acima servem para o selenium entrar no site statusinvest, onde tiraremos nossas informações

py.keyDown('win')
py.press('up')
py.keyUp('win')

relatorio = []

for c in df['SETOR']:
    navegador.find_element('xpath', '//*[@id="main-nav-nav"]/div/div/div/ul/li[2]/a/i').click()
    navegador.find_element('xpath', '//*[@id="main-search"]/div[1]/span[1]/input[2]').send_keys(c)
    try:
        sl(3)
        navegador.find_element('xpath', '//*[@id="main-search"]/div[2]/div/div/a').click()
    except:
        sl(2)
        navegador.find_element('xpath', '//*[@id="main-search"]/div[2]/div/div/a').click()

    relatorio.append(navegador.find_element('xpath', '//*[@id="earning-section"]/div[6]').text)
# Out:
# https://statusinvest.com.br/

# %%
df = pd.DataFrame(zip(relatorio), columns=['RELATÓRIO'])
display(df)
# Out:
#                                            RELATÓRIO
# 0  O último dividendo do ABCB4 foi de R$0,37 por ...
# 1  O último dividendo do ALUP11 foi de R$0,12 por...
# 2  O último dividendo do CMIG3 foi de R$0,45 por ...
# 3  O último dividendo do CMIG4 foi de R$0,45 por ...
# 4  O último dividendo do JBSS3 foi de R$1,00 por ...
# 5  O último dividendo do SAPR11 foi de R$1,45 por...
# 6  O último dividendo do SAPR4 foi de R$0,30 por ...
# 7  O último dividendo do SLCE3 foi de R$2,60 por ...
# 8  O último dividendo do VALE3 foi de R$2,12 por ...

# %%
df.to_excel('melhores_ações_julho.xlsx', index=False)

# %%
df2 = pd.read_excel('melhores_fundos.xlsx')
#planilha em excel adquirida por meio do site statusinvest, no qual nos fornece-a gratuitamente 
display(df2)
# df será a variável que terá nosso DataFrame
# Out:
#      SETOR                 TIPO     SETOR.1  COTAÇÃO ATUAL  MINIMO  MAXIMO  \
# 0   AFHI11  Fundos Imobiliários      Papéis          97.89   92.17  101.48
# 1   CACR11  Fundos Imobiliários      Papéis         105.39   95.00  106.98
# 2   CVBI11  Fundos Imobiliários      Papéis          93.00   84.59   98.39
# 3   DEVA11  Fundos Imobiliários      Papéis          63.03   44.05   99.80
# 4   KNCR11  Fundos Imobiliários      Papéis          98.41   93.00  103.00
# 5   MCHF11  Fundos Imobiliários      Papéis           9.33    8.07    9.87
# 6   MCHY11  Fundos Imobiliários      Papéis         112.00  102.27  119.99
# 7   MXRF11  Fundos Imobiliários      Papéis          10.72    9.61   10.97
# 8   RBHG11  Fundos Imobiliários      Papéis          87.65   79.99   90.24
# 9   RBRX11  Fundos Imobiliários  Indefinido          91.80   79.72  100.00
# 10  RBRY11  Fundos Imobiliários      Papéis         100.68   90.31  104.79
# 11  RPRI11  Fundos Imobiliários      Papéis          99.29   90.15  101.76
# 12  RZAK11  Fundos Imobiliários      Papéis          93.45   85.22  104.56
# 13  RZTR11  Fundos Imobiliários       Misto          93.51   80.26  106.39
# 14  SNCI11  Fundos Imobiliários      Papéis         100.02   91.30  103.95
# 15  URPR11  Fundos Imobiliários      Papéis          97.26   87.50  108.96
# 16  VGHF11  Fundos Imobiliários       Misto           9.57    8.65    9.97
# 17  VGIR11  Fundos Imobiliários      Papéis           9.64    9.12   10.14
# 18  WHGR11  Fundos Imobiliários  Indefinido           9.44    8.19    9.99
#
#     DIVIDEND YIELD  LIQUIDEZ DIÁRIA  P/VP  CAGR LUCRO  PATRIMÔNIO LÍQUIDO  \
# 0            13.45        755817.46  1.02        0.00           288774480
# 1            16.94        577898.73  1.02        0.44           186195662
# 2            12.38       3093372.73  0.98        1.21          1049548114
# 3            16.04       2120999.85  0.67        0.00          1322282171
# 4            14.08      16554048.27  0.98        3.67          5753493521
# 5            13.72       1218884.62  0.99        0.00           304370939
# 6            16.79        606346.12  1.11        0.00           362457889
# 7            12.31      12335253.46  1.07       -0.52          2274793907
# 8            15.22        668372.54  0.97        1.03           156875339
# 9            15.44        512641.81  0.97        0.00           178796957
# 10           14.06       1420929.08  1.01        0.23           550260294
# 11           14.70        501132.81  0.98        0.00           227346027
# 12           17.78       3591251.69  1.01        0.00           817479129
# 13           13.06       1963018.04  0.98        0.00          1050763744
# 14           12.95        649472.77  1.01        0.00           414277551
# 15           15.89       2401713.08  0.97        0.00          1170990482
# 16           13.17       2015224.58  1.03        0.00           677023977
# 17           15.45       4027691.81  1.00        4.08           992969874
# 18           12.08        698637.88  0.94        0.00           253157824
#
#          CAIXA  LUCRO
# 0    295574254      0
# 1    190485469      0
# 2   1023951204      0
# 3    885250551      0
# 4   5618924332      0
# 5    301865125      0
# 6    402054352      0
# 7   2423145187      0
# 8    151422562      0
# 9    172647158      0
# 10   558452227      0
# 11   222583854      0
# 12   823096853      0
# 13  1033100163      0
# 14   420084000      0
# 15  1135534620      0
# 16   697550094      0
# 17   995047615      0
# 18   236845173      0

# %%
navegador = webdriver.Chrome()
navegador.get('https://www.google.com')
link = 'https://statusinvest.com.br/'
navegador.get(link)
print(link)
#as funcões acima servem para o selenium entrar no site statusinvest, onde tiraremos nossas informações

py.keyDown('win')
py.press('up')
py.keyUp('win')

relatorio = []

for c in df2['SETOR']:
    navegador.find_element('xpath', '//*[@id="main-nav-nav"]/div/div/div/ul/li[2]/a/i').click()
    navegador.find_element('xpath', '//*[@id="main-search"]/div[1]/span[1]/input[2]').send_keys(c)
    try:
        sl(3)
        navegador.find_element('xpath', '//*[@id="main-search"]/div[2]/div/div/a').click()
    except:
        try:
            sl(1.5)
            navegador.find_element('xpath', '//*[@id="main-search"]/div[2]/div/div/a').click()
        except:
            sl(1.5)
            navegador.find_element('xpath', '//*[@id="main-search"]/div[2]/div/div/a').click()
            
    relatorio.append(navegador.find_element('xpath', '//*[@id="earning-section"]/div[6]').text)
# Out:
# https://statusinvest.com.br/

# %%
df2 = pd.DataFrame(zip(relatorio), columns=['RELATÓRIO'])
display(df2)
# Out:
#                                             RELATÓRIO
# 0   O último rendimento do AFHI11 foi de R$1,10 po...
# 1   O último rendimento do CACR11 foi de R$1,61 po...
# 2   O último rendimento do CVBI11 foi de R$1,10 po...
# 3   O último rendimento do DEVA11 foi de R$0,65 po...
# 4   O último rendimento do KNCR11 foi de R$1,24 po...
# 5   O último rendimento do MCHF11 foi de R$0,10 po...
# 6   O último rendimento do MCHY11 foi de R$1,40 po...
# 7   O último rendimento do MXRF11 foi de R$0,12 po...
# 8   O último rendimento do RBHG11 foi de R$1,05 po...
# 9   O último rendimento do RBRX11 foi de R$1,17 po...
# 10  O último rendimento do RBRY11 foi de R$1,25 po...
# 11  O último rendimento do RPRI11 foi de R$1,30 po...
# 12  O último rendimento do RZAK11 foi de R$1,25 po...
# 13  O último rendimento do RZTR11 foi de R$0,85 po...
# 14  O último rendimento do SNCI11 foi de R$1,10 po...
# 15  O último rendimento do URPR11 foi de R$1,33 po...
# 16  O último rendimento do VGHF11 foi de R$0,12 po...
# 17  O último rendimento do VGIR11 foi de R$0,12 po...
# 18  O último rendimento do WHGR11 foi de R$0,10 po...

# %%
#df2.to_excel('Análise_fundos_julho.xlsx', index=False)
