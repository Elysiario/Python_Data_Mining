# %%
import pyautogui as py 
import pandas as pd 
from time import sleep as sl
import matplotlib.pyplot as plt

df = pd.read_excel('projeto_BI.xlsx') 
display(df)
#display(df['TICKER'][9])
# Out:
#     TICKER
# 0    OIBR4
# 1    OMGE3
# 2    ONCO3
# 3    OPCT3
# 4    ORVR3
# ..     ...
# 173  WHRL4
# 174  WIZS3
# 175  WLMM3
# 176  WLMM4
# 177  YDUQ3
#
# [178 rows x 1 columns]

# %%
py.PAUSE= 0.3
py.press('win')
sl(0.7)
py.write('excel')
sl(0.7)
py.press('enter')
sl(2.5)
py.hotkey('ctrl', 'n')
py.press('enter')
py.press('enter')
py.keyDown('win')
py.press('down')
py.keyUp('win')
py.keyDown('win')
py.press('down')
py.keyUp('win')
sl(2)
py.hotkey('ctrl', 't')
sl(0.7)
py.click(x=930, y=105)
sl(0.7)
py.click(x=962, y=212)
sl(2.2)
py.click(x=626, y=175)

#cont = 0
for c in df['TICKER']:
    #cont +=1
    py.write(c)
    sl(3.7)
    py.click(x=776, y=287)
    sl(1)
    #cotação atual
    py.leftClick(x=327, y=554)
    py.keyDown('shift')
    py.leftClick(x=457, y=557)
    py.keyUp('shift')
    py.hotkey('ctrl', 'c')
    py.moveTo(x=1552, y=1079)
    py.click(x=1263, y=1039)
    py.keyDown('win')
    py.press('up')
    py.keyUp('win')
    py.write(c)
    py.write(' cotacao atual ')
    py.hotkey('ctrl', 'v')
    py.press('right')
    py.keyDown('win')
    py.press('down')
    py.keyUp('win')
    py.keyDown('win')
    py.press('down')
    py.keyUp('win')
    
    #preço mínimo
    py.leftClick(x=609, y=545)
    py.keyDown('shift')
    py.leftClick(x=709, y=542)
    py.keyUp('shift')
    py.hotkey('ctrl', 'c')
    py.moveTo(x=1552, y=1079)
    py.click(x=1263, y=1039)
    py.keyDown('win')
    py.press('up')
    py.keyUp('win')
    py.write(' preco minimo ')
    py.hotkey('ctrl', 'v')
    py.press('right')
    py.keyDown('win')
    py.press('down')
    py.keyUp('win')
    py.keyDown('win')
    py.press('down')
    py.keyUp('win')
    
    #preço máximo
    py.leftClick(x=882, y=547)
    py.keyDown('shift')
    py.leftClick(x=1007, y=544)
    py.keyUp('shift')
    py.hotkey('ctrl', 'c')
    py.moveTo(x=1552, y=1079)
    py.click(x=1263, y=1039)
    py.keyDown('win')
    py.press('up')
    py.keyUp('win')
    py.write(' preco maximo ')
    py.hotkey('ctrl', 'v')
    py.press('right')
    py.keyDown('win')
    py.press('down')
    py.keyUp('win')
    py.keyDown('win')
    py.press('down')
    py.keyUp('win')
    
    #dividend yield
    py.leftClick(x=1167, y=554)
    py.keyDown('shift')
    py.leftClick(x=1265, y=550)
    py.keyUp('shift')
    py.hotkey('ctrl', 'c')
    py.moveTo(x=1552, y=1079)
    py.click(x=1263, y=1039)
    py.keyDown('win')
    py.press('up')
    py.keyUp('win')
    py.write(' dividend yield ')
    py.hotkey('ctrl', 'v')
    py.press('right')
    py.press('enter')
    py.press('left')
    py.press('left')
    py.press('left')
    py.press('left')
    py.keyDown('win')
    py.press('down')
    py.keyUp('win')
    py.keyDown('win')
    py.press('down')
    py.keyUp('win')
    py.click(x=634, y=177)
    py.hotkey('ctrl', 'a')
    py.press('delete')
    #if cont == 4:
        #break

# %%
sl(4.5)
py.position()
